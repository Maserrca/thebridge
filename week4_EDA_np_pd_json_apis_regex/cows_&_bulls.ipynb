# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
cows = 0
x = "1111"
while cows < 4:
    bulls = 0
    cows = 0

    entrada = input("Escribe un número")
    for i, elem in enumerate(x):
        if elem == entrada[i]:
            cows += 1
        elif elem in entrada:
            bulls += 1 
        if entrada == "STOP":
            print("stop")
    print (f"{cows} cows, {bulls} bulls")
# Out:
# 1 cows, 3 bulls
# 0 cows, 0 bulls
# 2 cows, 2 bulls
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-e943bc2fcca6> in <module>
#       7     entrada = input("Escribe un número")
#       8     for i, elem in enumerate(x):
# ----> 9         if elem == entrada[i]:
#      10             cows += 1
#      11         elif elem in entrada:
#
# IndexError: string index out of range

# %%
def cows_bulls(cows=0, bulls=0):
    entrada = input("Escribe un número")
    for i, elem in enumerate(x):
        if elem == entrada[i]:
            cows += 1
        elif elem in entrada:
            bulls += 1 
        if entrada == "STOP":
            print("stop")
    print (f"{cows} cows, {bulls} bulls")

# %%
import random
random.ramdit(0,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-eb9bb6a6bea3> in <module>
#       1 import random
# ----> 2 random.ramdit(0,10)
#
# AttributeError: module 'random' has no attribute 'ramdit'

# %%
x = "1111"
while cows < 4:
    bulls = 0
    cows = 0
    cont = 0
    entrada = input("Escribe un número")
    for i, elem in enumerate(x):
        if elem == entrada[i]:
            cows += 1
        if elem in entrada[cont]:
            bulls += 1 
            cont +=1
        if entrada == "STOP":
            print("stop")
    print (f"{cows} cows, {bulls} bulls")
