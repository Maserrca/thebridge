# %%
import sys, os
import numpy as np
import pandas as pd
import utils.mining_data_tb as mn
import utils.visualization_tb as vv
#Quitar el comentario para ejecutar, espero que funcione fuera de mi ordenador
#import utils.plotly_tb as pp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

dirr = os.path.dirname
path = dirr(os.getcwd())
print(path)
sys.path.append(path)
# Out:
# d:\COSAS\BOOTCAMP\thebridge\EDA
# prueba
# d:\COSAS\BOOTCAMP\thebridge\EDA

# %%
df_clean = mn.clean_1("homicides_data.csv")
# Out:
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Year']
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Decade'].apply(lambda x: str(x))
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Decade'].str[:3]
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Zeros'] = '0'
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Decade'] + df_clean['Zeros']
# C:\Users\marin\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Enc_Solved'] = df_clean['Solved']
# C:\Users\marin\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
agrupado = mn.sum_solved(df_clean)

# %%
population3 = mn.clean_population('population.csv')

# %%
completo = mn.converger(agrupado,population3)

# %%
completo
# Out:
#      Decade          State  Enc_Solved  Enc_NoSolved Population Density  \
# 0      1970        Alabama      1721.0         171.0               68,0
# 1      1970         Alaska       134.0          43.0                0,5
# 2      1970        Arizona       605.0         192.0               15,6
# 3      1970       Arkansas       668.0          45.0               37,0
# 4      1970     California      5184.0        2648.0              128,1
# ..      ...            ...         ...           ...                ...
# 245    2010       Virginia      3246.0         797.0              202,6
# 246    2010     Washington      1719.0         340.0              101,2
# 247    2010  West Virginia       653.0         100.0               77,1
# 248    2010      Wisconsin      1696.0         297.0              105,0
# 249    2010        Wyoming       117.0          11.0                5,8
#
#     Resident Population
# 0             3.444.165
# 1               300.382
# 2             1.770.900
# 3             1.923.295
# 4            19.953.134
# ..                  ...
# 245           8.001.024
# 246           6.724.540
# 247           1.852.994
# 248           5.686.986
# 249             563.626
#
# [250 rows x 6 columns]

# %%
completo = mn.operables(completo)

# %%
completo.to_csv(path + os.sep + 'data' + os.sep + 'paramatriz.csv', index = False)

# %%
completo
# Out:
#      Decade          State  Enc_Solved  Enc_NoSolved  Population Density  \
# 0      1980        Alabama        3421           370                76.9
# 1      1980         Alaska         369            87                 0.7
# 2      1980        Arizona        1688           684                23.9
# 3      1980       Arkansas        1487           164                43.9
# 4      1980     California       15453          7325               151.9
# ..      ...            ...         ...           ...                 ...
# 195    2010       Virginia        3246           797               202.6
# 196    2010     Washington        1719           340               101.2
# 197    2010  West Virginia         653           100                77.1
# 198    2010      Wisconsin        1696           297               105.0
# 199    2010        Wyoming         117            11                 5.8
#
#      Resident Population
# 0                3893888
# 1                 401851
# 2                2718215
# 3                2286435
# 4               23667902
# ..                   ...
# 195              8001024
# 196              6724540
# 197              1852994
# 198              5686986
# 199               563626
#
# [200 rows x 6 columns]

# %%
df_1 = mn.sumatorios(completo)
# Out:
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completo['Casos Totales'] = completo['Enc_Solved'] + completo['Enc_NoSolved']
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completo['Porcentaje Resueltos'] = (completo['Enc_Solved'] / completo['Casos Totales']) * 100
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completo['Porcentaje No Resueltos'] = (completo['Enc_NoSolved'] / completo['Casos Totales']) * 100

# %%
df_1
# Out:
#      Decade          State  Enc_Solved  Enc_NoSolved  Population Density  \
# 0      1980        Alabama        3421           370                76.9
# 1      1980         Alaska         369            87                 0.7
# 2      1980        Arizona        1688           684                23.9
# 3      1980       Arkansas        1487           164                43.9
# 4      1980     California       15453          7325               151.9
# ..      ...            ...         ...           ...                 ...
# 195    2010       Virginia        3246           797               202.6
# 196    2010     Washington        1719           340               101.2
# 197    2010  West Virginia         653           100                77.1
# 198    2010      Wisconsin        1696           297               105.0
# 199    2010        Wyoming         117            11                 5.8
#
#      Resident Population  Casos Totales  Porcentaje Resueltos  \
# 0                3893888           3791             90.240042
# 1                 401851            456             80.921053
# 2                2718215           2372             71.163575
# 3                2286435           1651             90.066626
# 4               23667902          22778             67.841777
# ..                   ...            ...                   ...
# 195              8001024           4043             80.286916
# 196              6724540           2059             83.487130
# 197              1852994            753             86.719788
# 198              5686986           1993             85.097842
# 199               563626            128             91.406250
#
#      Porcentaje No Resueltos
# 0                   9.759958
# 1                  19.078947
# 2                  28.836425
# 3                   9.933374
# 4                  32.158223
# ..                       ...
# 195                19.713084
# 196                16.512870
# 197                13.280212
# 198                14.902158
# 199                 8.593750
#
# [200 rows x 9 columns]

# %%
df_US = mn.para_us(df_1)

# %%
df_US
# Out:
#                       Enc_Solved  Enc_NoSolved  Population Density  \
# Decade State
# 1980   Alabama              3421           370                76.9
#        Alaska                369            87                 0.7
#        Arizona              1688           684                23.9
#        Arkansas             1487           164                43.9
#        California          15453          7325               151.9
# ...                          ...           ...                 ...
# 2010   Virginia             3246           797               202.6
#        Washington           1719           340               101.2
#        West Virginia         653           100                77.1
#        Wisconsin            1696           297               105.0
#        Wyoming               117            11                 5.8
#
#                       Resident Population  Casos Totales  \
# Decade State
# 1980   Alabama                    3893888           3791
#        Alaska                      401851            456
#        Arizona                    2718215           2372
#        Arkansas                   2286435           1651
#        California                23667902          22778
# ...                                   ...            ...
# 2010   Virginia                   8001024           4043
#        Washington                 6724540           2059
#        West Virginia              1852994            753
#        Wisconsin                  5686986           1993
#        Wyoming                     563626            128
#
#                       Porcentaje Resueltos  Porcentaje No Resueltos
# Decade State
# 1980   Alabama                   90.240042                 9.759958
#        Alaska                    80.921053                19.078947
#        Arizona                   71.163575                28.836425
#        Arkansas                  90.066626                 9.933374
#        California                67.841777                32.158223
# ...                                    ...                      ...
# 2010   Virginia                  80.286916                19.713084
#        Washington                83.487130                16.512870
#        West Virginia             86.719788                13.280212
#        Wisconsin                 85.097842                14.902158
#        Wyoming                   91.406250                 8.593750
#
# [200 rows x 7 columns]

# %%
df_curious = mn.clean_curious("homicides_data.csv")

# %%
df_curious
# Out:
#           State   OffSex                            Weapon  \
# 0        Alaska     Male   Handgun - pistol, revolver, etc
# 1        Alaska     Male   Handgun - pistol, revolver, etc
# 2        Alaska     Male   Handgun - pistol, revolver, etc
# 3        Alaska     Male   Handgun - pistol, revolver, etc
# 4        Alaska   Female       Knife or cutting instrument
# ...         ...      ...                               ...
# 652445  Wyoming     Male   Handgun - pistol, revolver, etc
# 652446  Wyoming     Male       Knife or cutting instrument
# 652447  Wyoming     Male  Blunt object - hammer, club, etc
# 652448  Wyoming  Unknown                           Shotgun
# 652449  Wyoming     Male          Firearm, type not stated
#
#                              Circumstance
# 0                         Other arguments
# 1                         Other arguments
# 2                                   Other
# 3                         Other arguments
# 4                         Other arguments
# ...                                   ...
# 652445              Other - not specified
# 652446  Brawl due to influence of alcohol
# 652447  Brawl due to influence of alcohol
# 652448                 Narcotic drug laws
# 652449                              Other
#
# [652450 rows x 4 columns]

# %%
df_US.to_csv(path + os.sep + 'data' + os.sep + 'dfUS.csv', index=False)

# %%
df_curious.to_csv(path + os.sep + 'data' + os.sep + 'curioso.csv', index = False)

# %%
df_1.to_csv(path + os.sep + 'data' + os.sep +'finaldf.csv', index = False)

# %%
df_US = mn.para_us(df_1)

# %%
df_US
# Out:
#                       Enc_Solved  Enc_NoSolved  Population Density  \
# Decade State
# 1980   Alabama              3421           370                76.9
#        Alaska                369            87                 0.7
#        Arizona              1688           684                23.9
#        Arkansas             1487           164                43.9
#        California          15453          7325               151.9
# ...                          ...           ...                 ...
# 2010   Virginia             3246           797               202.6
#        Washington           1719           340               101.2
#        West Virginia         653           100                77.1
#        Wisconsin            1696           297               105.0
#        Wyoming               117            11                 5.8
#
#                       Resident Population  Casos Totales  \
# Decade State
# 1980   Alabama                    3893888           3791
#        Alaska                      401851            456
#        Arizona                    2718215           2372
#        Arkansas                   2286435           1651
#        California                23667902          22778
# ...                                   ...            ...
# 2010   Virginia                   8001024           4043
#        Washington                 6724540           2059
#        West Virginia              1852994            753
#        Wisconsin                  5686986           1993
#        Wyoming                     563626            128
#
#                       Porcentaje Resueltos  Porcentaje No Resueltos
# Decade State
# 1980   Alabama                   90.240042                 9.759958
#        Alaska                    80.921053                19.078947
#        Arizona                   71.163575                28.836425
#        Arkansas                  90.066626                 9.933374
#        California                67.841777                32.158223
# ...                                    ...                      ...
# 2010   Virginia                  80.286916                19.713084
#        Washington                83.487130                16.512870
#        West Virginia             86.719788                13.280212
#        Wisconsin                 85.097842                14.902158
#        Wyoming                   91.406250                 8.593750
#
# [200 rows x 7 columns]

# %%
matriz = pd.read_csv(path + os.sep + 'data' + os.sep + 'paramatriz.csv') #Se guardó el csv porque con las funciones sin retornar nada no habia otro modo de acceder a ese dataframe, despues se sobreescribe y no permitía tampoco cambiarlo el nombre porque volvia a retornar nada
vv.matriz(df_matriz=matriz)
# Out:
# <AxesSubplot:>

# %%
vv.tendencia_total(df_1)
# Out:
# Text(0.5, 1.0, 'Asesinatos en EEUU')

# %%
vv.tendecia_casos(df_1)

# %%
#Dados los problemas que ha dado plotly el resto de gráficos salen desde el archivo de utils/plotly.py habrá que importar plotly sobre este jupyter. Si no se dan las funciones, pueden ejecutarse en el py

# %%
barras(df_1)

# %%
weapons(df_curioso)

# %%
circunstancia(df_curioso)

# %% [markdown]
# a.Was it possible to demonstrate the hypothesis? Why?
#
# Parece verse que no hay conexiónn entre la densidad de población con los casos en porcentaje ni los casos resueltos en general
# por lo que no se cumpliría la hipótesis.

# %% [markdown]
# b.What can you conclude about your data study?
#
# De media no parece que haya una correlación entre la resolución de los casos y la densidad de población. Por lo que no parece que los sitios con una menor densidad de población tengan mayor porcentaje de casos o de casos resueltos a mesar de lo que comunmente se piensa.
# Sin embargo, si nos dividimos por estado, como se puede ver en los gráficos de tableu incluidos en la carpeta documentation, sí parece que en determinados estados,  existe un mayor porcentaje de casos resueltos segun la densidad de población es más baja.
# También se ve que los asesinatos han disminuido con el tiempo, aunque porcentualmente sse mantienen etables los caos no resueltos a nivel general y el porcentaje los casos no resueltos parece tender a ascender y los resueltos tienden a descender.

# %% [markdown]
# c.What would you change if you need to do another EDAproject?
#
# Primero de todo, tendría cuidado con el tiempo disponible para ello pero la verdad que cambiaria casi todo, haría el data mining de forma distinta para evitar los problemas de copia de dataframes que enlentecieron aún más el proceso e hicieron a los dataframe aun más sensibles a cualquien cambio lo que hacía que saltaran fallos de forma constante.
# Por otro lado tendría especial cuidado con los gráficos y la interpretación de los mismos que es una parte que me queda por pulir bastante.
# Organizaria todo por pasos mas pequeños y me cnetraria en hacer una cosa detrás de otra y no todas a la vez y sobretodo cambiaría dejarme llevar por la presión por asumir que puedo llegar hasta donde llegue y eso no está mal.

# %% [markdown]
# d.What do you learn doing this project?
#
# Muchisimas cosas, flask y streamlit han sido las partes más nuevas, también he repasado todo el tema de las importaciones y afianzado los conocimientos, he aprendido de rebote a modificar las tablas en sql aunque aquí no se vea reflejado pero para organizarme las tablas y conocer el dataset y para paliar todos los contantes errores que me fui encontrando, pero todo lo que he aprendido no lo podría enumerar. He aprendido como no hacer un proyecto de EDA, cómo hacerlo en gran medida, que me frustro con facilidad y soy demasiado perfeccionista  (por eso me duele tanto entregar algo tan a medias) y  por último he aprendido sobretodo que me queda muchisimo por aprender y que aprendo muy despacio. Pero al menos ahora puedo decir que me gusta lo que estoy aprendiendo.

# %%
No está limpio, no está precioso, no esta perfectó... pero funciona.
