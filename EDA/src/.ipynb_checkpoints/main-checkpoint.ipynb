# %%
import sys, os
import numpy as np
import pandas as pd
import utils.mining_data_tb as mn
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-40b2a8865123> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import utils.mining_data_tb as mn
#       5 import matplotlib.pyplot as plt
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'utils'

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
df_clean = mn.clean_1("homicides_data.csv")
# Out:
# D:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Year']
# D:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Decade'] = df_clean['Decade'].apply(lambda x: str(x))
# D:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
agrupado = mn.sum_solved(df_clean)

# %%
population3 = mn.clean_population('population.csv')

# %%
population3
# Out:
# Medidas  Decade           State Population Density Resident Population
# 0          1970         Alabama               68,0           3.444.165
# 1          1970          Alaska                0,5             300.382
# 2          1970         Arizona               15,6           1.770.900
# 3          1970        Arkansas               37,0           1.923.295
# 4          1970      California              128,1          19.953.134
# ..          ...             ...                ...                 ...
# 255        2010      Washington              101,2           6.724.540
# 256        2010   West Virginia               77,1           1.852.994
# 257        2010       Wisconsin              105,0           5.686.986
# 258        2010         Wyoming                5,8             563.626
# 259        2010  United States1               87,4         308.745.538
#
# [260 rows x 4 columns]

# %%
completo = mn.converger(agrupado,population3)

# %%
df_1 = mn.operables(completo)
# Out:
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completo['Casos Totales'] = completo['Enc_Solved'] + completo['Enc_NoSolved']
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completo['Porcentaje Resueltos'] = (completo['Enc_Solved'] / completo['Casos Totales']) * 100
# d:\COSAS\BOOTCAMP\thebridge\EDA\src\utils\mining_data_tb.py:74: SettingWithCopyWarning:
# ...

# %%
df_1
# Out:
#      Decade          State  Enc_Solved  Enc_NoSolved  Population Density  \
# 50     1980        Alabama        3421           370                76.9
# 51     1980         Alaska         369            87                 0.7
# 52     1980        Arizona        1688           684                23.9
# 53     1980       Arkansas        1487           164                43.9
# 54     1980     California       15453          7325               151.9
# ..      ...            ...         ...           ...                 ...
# 245    2010       Virginia        3246           797               202.6
# 246    2010     Washington        1719           340               101.2
# 247    2010  West Virginia         653           100                77.1
# 248    2010      Wisconsin        1696           297               105.0
# 249    2010        Wyoming         117            11                 5.8
#
#      Resident Population  Casos Totales  Porcentaje Resueltos  \
# ...

# %%
df_2 = df_1.groupby('Decade').sum()
# Out:
#         Enc_Solved  Enc_NoSolved  Population Density  Resident Population  \
# Decade
# 1980        123676         45279             17317.8            225598651
# 1990        112332         52624             17314.1            247706409
# 2000         88341         36736             17491.5            280373587
# 2010         87580         36763             18586.5            307692971
#
#         Casos Totales  Porcentaje Resueltos  Porcentaje No Resueltos
# Decade
# 1980           168955           3894.471713              1105.528287
# 1990           164956           3818.596106              1181.403894
# 2000           125077           3876.083798              1123.916202
# 2010           124343           3835.688522              1164.311478

# %%
sns.lineplot(data=df_2, x="Decade", y="Casos Totales")
# Out:
# <AxesSubplot:xlabel='Decade', ylabel='Casos Totales'>

# %%
sns.relplot(x='Decade', y='Casos totales', data = df_2, kind ='line',estimator =sum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-b5e0d9cab22a> in <module>
# ----> 1 sns.relplot(x='Decade', y='Casos totales', data = df_2, kind ='line',estimator =sum)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     941         data=data,
#     942         variables=plotter.get_semantics(locals()),
# ...

# %%
df_1.to_csv('finaldf.csv', index = False)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1980 to 2010
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Enc_Solved               4 non-null      int64
#  1   Enc_NoSolved             4 non-null      int64
#  2   Population Density       4 non-null      float64
#  3   Resident Population      4 non-null      int64
#  4   Casos Totales            4 non-null      int64
#  5   Porcentaje Resueltos     4 non-null      float64
#  6   Porcentaje No Resueltos  4 non-null      float64
# dtypes: float64(3), int64(4)
# memory usage: 428.0 bytes

# %%
f, ax = plt.subplots(figsize=(13, 10))
sns.heatmap(df_1.corr(),
           vmin = -1,
           vmax = 1,
            annot = True,
           linewidths = .5)
# Out:
# <AxesSubplot:>

# %%
dfhis =px.df_1.tips()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9b7740414d36> in <module>
# ----> 1 dfhis =px.df_1.tips()
#
# NameError: name 'px' is not defined
