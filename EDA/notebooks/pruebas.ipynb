# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def clean_curious():
    df = pd.read_csv("homicides_data.csv")
    df = df.drop(['StateName', 'Subcircum', 'FileDate'], axis =1)
    df = df.drop_duplicates()
    df = df[df.ActionType != "Adjustment"]
    df.drop("ActionType", axis=1, inplace = True)
    df.reset_index(inplace = True)
    df_curious = df[['State','OffSex','Weapon', 'Circumstance']]
    return df_curious
df_curious = clean_curious()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-85a54d4b3998> in <module>
#       8     df_curious = df[['State','OffSex','Weapon', 'Circumstance']]
#       9     return df_curious
# ---> 10 df_curious = clean_curious()
#
# <ipython-input-3-85a54d4b3998> in clean_curious()
#       1 def clean_curious():
# ----> 2     df = pd.read_csv("homicides_data.csv")
#       3     df = df.drop(['StateName', 'Subcircum', 'FileDate'], axis =1)
#       4     df = df.drop_duplicates()
#       5     df = df[df.ActionType != "Adjustment"]
#
# ...

# %%
df_curious
# Out:
#          OffSex                            Weapon  \
# 0          Male   Handgun - pistol, revolver, etc
# 1          Male   Handgun - pistol, revolver, etc
# 2          Male   Handgun - pistol, revolver, etc
# 3          Male   Handgun - pistol, revolver, etc
# 4        Female       Knife or cutting instrument
# ...         ...                               ...
# 652445     Male   Handgun - pistol, revolver, etc
# 652446     Male       Knife or cutting instrument
# 652447     Male  Blunt object - hammer, club, etc
# 652448  Unknown                           Shotgun
# 652449     Male          Firearm, type not stated
#
#                              Circumstance
# 0                         Other arguments
# 1                         Other arguments
# 2                                   Other
# 3                         Other arguments
# 4                         Other arguments
# ...                                   ...
# 652445              Other - not specified
# ...

# %%
total = sns.displot(df_curious.Weapon)
total.set(ylabel = "Weapon", xlabel = 'Count', title = "Total")
sns.despine()
